# %% [markdown]
# # Exploration
#
# Imports from `scripts/lib/` rather than reimplementing pipeline logic.
# Run `python scripts/0X_*.py` for anything that should be cached to disk
# (data audits, ESM-2 scoring). Use notebooks for plotting and one-off checks.
#
# Requires `data/raw/mthfrModel/` to be populated first -- see README.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from scripts.lib.io import load_primary_maps, load_derived_maps

maps = load_primary_maps()
maps.head()

# %%
import matplotlib.pyplot as plt

maps.groupby(['background', 'folinate_ugml'])['score'].median().unstack('background').plot(marker='o')
plt.ylabel('median score')
plt.xlabel('folinate (ug/mL)')
plt.title('Sanity check: median fitness by condition')
